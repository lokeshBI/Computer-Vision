# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
path = 'cat.2012.jpg'

# %% [markdown]
# ### reading images

# %%
img1 = cv2.imread(path, 1) # 1 = colored image
img2 = cv2.imread(path, 0) # 0 = gray image

# %%
img1[:1]
# Out:
# array([[[ 26,  23,  32],
#         [ 29,  26,  35],
#         [ 30,  24,  35],
#         ...,
#         [134, 148, 147],
#         [129, 143, 142],
#         [122, 136, 135]]], dtype=uint8)

# %%
img2
# Out:
# array([[ 26,  29,  28, ..., 146, 141, 134],
#        [ 26,  29,  26, ..., 144, 139, 133],
#        [ 28,  29,  25, ..., 128, 123, 117],
#        ...,
#        [ 48,  54,  63, ..., 147, 148, 151],
#        [ 56,  62,  71, ..., 136, 139, 143],
#        [ 61,  68,  77, ..., 127, 131, 136]], dtype=uint8)

# %%
print('shape of img1: {}'.format(img1.shape))
print('3 for 3 channels.i.e. red, blue, green', '\n')
print('shape of img2: {}'.format(img2.shape))
# Out:
# shape of img1: (375, 499, 3)
# 3 for 3 channels.i.e. red, blue, green
#
# shape of img2: (375, 499)

# %% [markdown]
# ### show image

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,5))
fig.suptitle('color   vs    grayscale')
ax1.imshow(img1)
ax2.imshow(img2, cmap = 'gray')
plt.show()

# %% [markdown]
# ### resizing

# %%
resize1 = cv2.resize(img1, (200,300))
plt.imshow(resize1, cmap= 'gray')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,5))
fig.suptitle('color   vs    grayscale')
ax1.imshow(cv2.resize(img1, (200,300)))
ax2.imshow(cv2.resize(img2,(800,800)), cmap = 'gray')
plt.show()

# %% [markdown]
# ### how to increaase size by double

# %%
# increasing it's size by double  
resize_image1 = cv2.resize(img1, (int(img1.shape[0]*2),int(img1.shape[1]*2)))
print('original shape of img1 :{}'.format(img1.shape))
plt.imshow(img1)
plt.show()
print('after resized : {}'.format(resize_image1.shape))
plt.imshow(resize_image1)
plt.show()
# Out:
# original shape of img1 :(375, 499, 3)
# after resized : (998, 750, 3)
